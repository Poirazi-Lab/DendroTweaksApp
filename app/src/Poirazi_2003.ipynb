# %%
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint

# %%
import dendrotweaks as dd

# %%
from dendrotweaks.morphology.io.reader import SWCReader
from dendrotweaks.morphology.io.factory import TreeFactory

# %%
model = dd.Model(name='Poirazi_2003', 
                 path_to_data='data')

# %%
model.print_directory_tree()
# Out:
# ├── csv
# │   ├── Poirazi_2003_groups.csv
# │   └── Poirazi_2003_stimuli.csv
# ├── json
# │   └── Poirazi_2003.json
# ├── membrane
# │   ├── Poirazi_2003_test.json
# │   └── Poirazi_2003_test2.json
# ├── mod
# │   ├── Kdr_dend
# │   │   ├── Kdr_dend.mod
# │   │   └── x86_64
# │   ├── Kdr_dend.mod
# │   ├── Kdr_soma
# │   │   ├── Kdr_soma.mod
# │   │   └── x86_64
# │   ├── Kdr_soma.mod
# │   ├── Na_dend
# │   │   ├── Na_dend.mod
# │   │   └── x86_64
# │   ├── Na_dend.mod
# │   ├── Na_soma
# │   │   ├── Na_soma.mod
# │   │   └── x86_64
# │   ├── Na_soma.mod
# │   ├── cal
# │   │   ├── cal.mod
# │   │   └── x86_64
# │   ├── cal.mod
# │   ├── calH
# │   │   ├── calH.mod
# │   │   └── x86_64
# │   ├── calH.mod
# │   ├── car
# │   │   ├── car.mod
# │   │   └── x86_64
# │   ├── car.mod
# │   ├── cat
# │   │   ├── cat.mod
# │   │   └── x86_64
# │   ├── cat.mod
# │   ├── h
# │   │   ├── h.mod
# │   │   └── x86_64
# │   ├── h.mod
# │   ├── kad
# │   │   ├── kad.mod
# │   │   └── x86_64
# │   ├── kad.mod
# │   ├── kap
# │   │   ├── kap.mod
# │   │   └── x86_64
# │   ├── kap.mod
# │   ├── kca
# │   │   ├── kca.mod
# │   │   └── x86_64
# │   ├── kca.mod
# │   ├── km
# │   │   ├── km.mod
# │   │   └── x86_64
# │   ├── km.mod
# │   ├── mykca
# │   │   ├── mykca.mod
# │   │   └── x86_64
# │   ├── mykca.mod
# │   ├── nap
# │   │   ├── nap.mod
# │   │   └── x86_64
# │   ├── nap.mod
# │   ├── somacar
# │   │   ├── somacar.mod
# │   │   └── x86_64
# │   └── somacar.mod
# ├── morphology
# │   ├── CA1_new.swc
# │   ├── Poirazi_2003.swc
# │   └── Poirazi_2003_modified.swc
# ├── python
# │   ├── Kdr_dend.py
# │   ├── Kdr_soma.py
# │   ├── Na_dend.py
# │   ├── Na_soma.py
# │   ├── __pycache__
# │   │   ├── Kdr_dend.cpython-311.pyc
# │   │   ├── Kdr_soma.cpython-311.pyc
# │   │   ├── Na_dend.cpython-311.pyc
# │   │   ├── Na_soma.cpython-311.pyc
# │   │   ├── cal.cpython-311.pyc
# │   │   ├── calH.cpython-311.pyc
# │   │   ├── car.cpython-311.pyc
# │   │   ├── cat.cpython-311.pyc
# │   │   ├── h.cpython-311.pyc
# │   │   ├── kad.cpython-311.pyc
# │   │   ├── kap.cpython-311.pyc
# │   │   ├── kca.cpython-311.pyc
# │   │   ├── km.cpython-311.pyc
# │   │   ├── mykca.cpython-311.pyc
# │   │   ├── nap.cpython-311.pyc
# │   │   └── somacar.cpython-311.pyc
# │   ├── cal.py
# │   ├── calH.py
# │   ├── car.py
# │   ├── cat.py
# │   ├── h.py
# │   ├── kad.py
# │   ├── kap.py
# │   ├── kca.py
# │   ├── km.py
# │   ├── mykca.py
# │   ├── nap.py
# │   └── somacar.py
# └── stimuli
#     ├── Poirazi_2003_test.csv
#     └── Poirazi_2003_test.json

# %% [markdown]
# # Morphology

# %%
model.list_morphologies()
# Out:
# ['CA1_new', 'Poirazi_2003', 'Poirazi_2003_modified']

# %%
model.load_morphology(file_name='Poirazi_2003_modified', soma_notation='3PS')
# Out:
# Removed 0 overlapping nodes.
# Removed 0 overlapping nodes.
# Converted soma to 3PS notation.
#   Elapsed time: 0.05 seconds
# Extended 178 nodes.
#   Elapsed time: 0.06 seconds
# Tree already sorted.
#   Elapsed time: 0.0 seconds
# Tree already sorted.
#   Elapsed time: 0.0 seconds
# Building sections in NEURON...
# 181 sections created.
# Adding group all...
# Adding group oblique...
# Adding group basal...
# Adding group tuft...
# Adding group trunk...
# Adding group axonal...
# Adding group somatic...

# %%
from dendrotweaks.morphology import validate_tree

# %%
model.sec_tree.soma.points
# Out:
# [•1, •0, •2]

# %%
validate_tree(model.point_tree)
# Out:
# Tree has a unique root node •0
# Tree is well connected
# Tree has no loops
# Tree is binary (not considering the root node)
# Tree is sorted

# %%
validate_tree(model.sec_tree)
# Out:
# Tree has a unique root node ••0
# Tree is well connected
# Tree has no loops
# Tree is binary (not considering the root node)
# Tree is sorted

# %%
focus = [sec for sec in model.sec_tree if sec.domain == 'soma']

# %%
for sec in focus[:]:
    focus += sec.children
focus = list(set(focus))

# %%
fig, ax = plt.subplots(figsize=(10, 10))
model.sec_tree.plot(ax, 
                    show_points=True,
                    show_lines=True,
                    show_domains=True,
                    annotate=True,
                    focus_sections=focus)

# %%
model.domains
# Out:
# {'oblique': <Domain(oblique, 72 sections)>,
#  'basal': <Domain(basal, 48 sections)>,
#  'tuft': <Domain(tuft, 22 sections)>,
#  'trunk': <Domain(trunk, 25 sections)>,
#  'axon': <Domain(axon, 13 sections)>,
#  'soma': <Domain(soma, 1 sections)>}

# %% [markdown]
# # Membrane

# %%
model.add_default_mechanisms(recompile=False)
# Out:
# ============================================================
# Adding mechanism vecstim to model...
# ============================================================
# Using precompiled mechanism "vecstim"
# Loaded mechanism "vecstim"
# Mechanism vecstim loaded to NEURON.
#
# ============================================================
# Adding mechanism AMPA_NMDA to model...
# ============================================================
# Using precompiled mechanism "AMPA_NMDA"
# Loaded mechanism "AMPA_NMDA"
# Mechanism AMPA_NMDA loaded to NEURON.
#
# ============================================================
# Adding mechanism Leak to model...
# ============================================================
# Using precompiled mechanism "Leak"
# Loaded mechanism "Leak"
# Mechanism Leak loaded to NEURON.
#
# ============================================================
# Adding mechanism AMPA to model...
# ============================================================
# Using precompiled mechanism "AMPA"
# Loaded mechanism "AMPA"
# Mechanism AMPA loaded to NEURON.
#
# ============================================================
# Adding mechanism GABAa to model...
# ============================================================
# Using precompiled mechanism "GABAa"
# Loaded mechanism "GABAa"
# Mechanism GABAa loaded to NEURON.
#
# ============================================================
# Adding mechanism NMDA to model...
# ============================================================
# Using precompiled mechanism "NMDA"
# Loaded mechanism "NMDA"
# Mechanism NMDA loaded to NEURON.

# %%
model.add_mechanisms(recompile=False)
# Out:
# Replacing SUFFIX Na_soma with SUFFIX Na_soma
# Overwritten data/Poirazi_2003/mod/Na_soma.mod
# Saved content to data/Poirazi_2003/python/Na_soma.py
# Registering Na_soma from Na_soma in data/Poirazi_2003/python
# Importing class Na_soma from module Na_soma.py
# ============================================================
# Adding mechanism Na_soma to model...
# ============================================================
# Using precompiled mechanism "Na_soma"
# Loaded mechanism "Na_soma"
# Mechanism Na_soma loaded to NEURON.
#
# Mechanism Na_soma added to model.
# Replacing SUFFIX cat with SUFFIX cat
# Overwritten data/Poirazi_2003/mod/cat.mod
# Saved content to data/Poirazi_2003/python/cat.py
# Registering cat from cat in data/Poirazi_2003/python
# Importing class cat from module cat.py
# ============================================================
# Adding mechanism cat to model...
# ============================================================
# Using precompiled mechanism "cat"
# Loaded mechanism "cat"
# Mechanism cat loaded to NEURON.
#
# Mechanism cat added to model.
# Replacing SUFFIX car with SUFFIX car
# Overwritten data/Poirazi_2003/mod/car.mod
# Saved content to data/Poirazi_2003/python/car.py
# Registering car from car in data/Poirazi_2003/python
# Importing class car from module car.py
# ============================================================
# Adding mechanism car to model...
# ============================================================
# Using precompiled mechanism "car"
# Loaded mechanism "car"
# Mechanism car loaded to NEURON.
#
# Mechanism car added to model.
# Replacing SUFFIX h with SUFFIX h
# Overwritten data/Poirazi_2003/mod/h.mod
# Saved content to data/Poirazi_2003/python/h.py
# Registering h from h in data/Poirazi_2003/python
# Importing class h from module h.py
# ============================================================
# Adding mechanism h to model...
# ============================================================
# Using precompiled mechanism "h"
# Loaded mechanism "h"
# Mechanism h loaded to NEURON.
#
# Mechanism h added to model.
# Replacing SUFFIX calH with SUFFIX calH
# Overwritten data/Poirazi_2003/mod/calH.mod
# Saved content to data/Poirazi_2003/python/calH.py
# Registering calH from calH in data/Poirazi_2003/python
# Importing class calH from module calH.py
# ============================================================
# Adding mechanism calH to model...
# ============================================================
# Using precompiled mechanism "calH"
# Loaded mechanism "calH"
# Mechanism calH loaded to NEURON.
#
# Mechanism calH added to model.
# Replacing SUFFIX nap with SUFFIX nap
# Overwritten data/Poirazi_2003/mod/nap.mod
# Saved content to data/Poirazi_2003/python/nap.py
# Registering nap from nap in data/Poirazi_2003/python
# Importing class nap from module nap.py
# ============================================================
# Adding mechanism nap to model...
# ============================================================
# Using precompiled mechanism "nap"
# Loaded mechanism "nap"
# Mechanism nap loaded to NEURON.
#
# Mechanism nap added to model.
# Replacing SUFFIX Kdr_dend with SUFFIX Kdr_dend
# Overwritten data/Poirazi_2003/mod/Kdr_dend.mod
# Saved content to data/Poirazi_2003/python/Kdr_dend.py
# Registering Kdr_dend from Kdr_dend in data/Poirazi_2003/python
# Importing class Kdr_dend from module Kdr_dend.py
# ============================================================
# Adding mechanism Kdr_dend to model...
# ============================================================
# Using precompiled mechanism "Kdr_dend"
# Loaded mechanism "Kdr_dend"
# Mechanism Kdr_dend loaded to NEURON.
#
# Mechanism Kdr_dend added to model.
# Replacing SUFFIX somacar with SUFFIX somacar
# Overwritten data/Poirazi_2003/mod/somacar.mod
# Saved content to data/Poirazi_2003/python/somacar.py
# Registering somacar from somacar in data/Poirazi_2003/python
# Importing class somacar from module somacar.py
# ============================================================
# Adding mechanism somacar to model...
# ============================================================
# Using precompiled mechanism "somacar"
# Loaded mechanism "somacar"
# Mechanism somacar loaded to NEURON.
#
# Mechanism somacar added to model.
# Replacing SUFFIX Na_dend with SUFFIX Na_dend
# Overwritten data/Poirazi_2003/mod/Na_dend.mod
# Saved content to data/Poirazi_2003/python/Na_dend.py
# Registering Na_dend from Na_dend in data/Poirazi_2003/python
# Importing class Na_dend from module Na_dend.py
# ============================================================
# Adding mechanism Na_dend to model...
# ============================================================
# Using precompiled mechanism "Na_dend"
# Loaded mechanism "Na_dend"
# Mechanism Na_dend loaded to NEURON.
#
# Mechanism Na_dend added to model.
# Replacing SUFFIX kca with SUFFIX kca
# Overwritten data/Poirazi_2003/mod/kca.mod
# Saved content to data/Poirazi_2003/python/kca.py
# Registering kca from kca in data/Poirazi_2003/python
# Importing class kca from module kca.py
# ============================================================
# Adding mechanism kca to model...
# ============================================================
# Using precompiled mechanism "kca"
# Loaded mechanism "kca"
# Mechanism kca loaded to NEURON.
#
# Mechanism kca added to model.
# Replacing SUFFIX kad with SUFFIX kad
# Overwritten data/Poirazi_2003/mod/kad.mod
# Saved content to data/Poirazi_2003/python/kad.py
# Registering kad from kad in data/Poirazi_2003/python
# Importing class kad from module kad.py
# ============================================================
# Adding mechanism kad to model...
# ============================================================
# Using precompiled mechanism "kad"
# Loaded mechanism "kad"
# Mechanism kad loaded to NEURON.
#
# Mechanism kad added to model.
# Replacing SUFFIX mykca with SUFFIX mykca
# Overwritten data/Poirazi_2003/mod/mykca.mod
# Saved content to data/Poirazi_2003/python/mykca.py
# Registering mykca from mykca in data/Poirazi_2003/python
# Importing class mykca from module mykca.py
# ============================================================
# Adding mechanism mykca to model...
# ============================================================
# Using precompiled mechanism "mykca"
# Loaded mechanism "mykca"
# Mechanism mykca loaded to NEURON.
#
# Mechanism mykca added to model.
# Replacing SUFFIX Kdr_soma with SUFFIX Kdr_soma
# Overwritten data/Poirazi_2003/mod/Kdr_soma.mod
# Saved content to data/Poirazi_2003/python/Kdr_soma.py
# Registering Kdr_soma from Kdr_soma in data/Poirazi_2003/python
# Importing class Kdr_soma from module Kdr_soma.py
# ============================================================
# Adding mechanism Kdr_soma to model...
# ============================================================
# Using precompiled mechanism "Kdr_soma"
# Loaded mechanism "Kdr_soma"
# Mechanism Kdr_soma loaded to NEURON.
#
# Mechanism Kdr_soma added to model.
# Replacing SUFFIX kap with SUFFIX kap
# Overwritten data/Poirazi_2003/mod/kap.mod
# Saved content to data/Poirazi_2003/python/kap.py
# Registering kap from kap in data/Poirazi_2003/python
# Importing class kap from module kap.py
# ============================================================
# Adding mechanism kap to model...
# ============================================================
# Using precompiled mechanism "kap"
# Loaded mechanism "kap"
# Mechanism kap loaded to NEURON.
#
# Mechanism kap added to model.
# Replacing SUFFIX cal with SUFFIX cal
# Overwritten data/Poirazi_2003/mod/cal.mod
# Saved content to data/Poirazi_2003/python/cal.py
# Registering cal from cal in data/Poirazi_2003/python
# Importing class cal from module cal.py
# ============================================================
# Adding mechanism cal to model...
# ============================================================
# Using precompiled mechanism "cal"
# Loaded mechanism "cal"
# Mechanism cal loaded to NEURON.
#
# Mechanism cal added to model.
# Replacing SUFFIX km with SUFFIX km
# Overwritten data/Poirazi_2003/mod/km.mod
# Saved content to data/Poirazi_2003/python/km.py
# Registering km from km in data/Poirazi_2003/python
# Importing class km from module km.py
# ============================================================
# Adding mechanism km to model...
# ============================================================
# Using precompiled mechanism "km"
# Loaded mechanism "km"
# Mechanism km loaded to NEURON.
#
# Mechanism km added to model.

# %% [markdown]
# # Groups

# %%
model.groups
# Out:
# {'all': SegmentGroup("all", domains=['oblique', 'basal', 'tuft', 'trunk', 'axon', 'soma']),
#  'oblique': SegmentGroup("oblique", domains=['oblique']),
#  'basal': SegmentGroup("basal", domains=['basal']),
#  'tuft': SegmentGroup("tuft", domains=['tuft']),
#  'trunk': SegmentGroup("trunk", domains=['trunk']),
#  'axonal': SegmentGroup("axonal", domains=['axon']),
#  'somatic': SegmentGroup("somatic", domains=['soma'])}

# %%
model.mechanisms
# Out:
# {'Leak': <Mechnaism(Leak)>,
#  'Na_soma': <Mechnaism(Na_soma)>,
#  'cat': <Mechnaism(cat)>,
#  'car': <Mechnaism(car)>,
#  'h': <Mechnaism(h)>,
#  'calH': <Mechnaism(calH)>,
#  'nap': <Mechnaism(nap)>,
#  'Kdr_dend': <Mechnaism(Kdr_dend)>,
#  'somacar': <Mechnaism(somacar)>,
#  'Na_dend': <Mechnaism(Na_dend)>,
#  'kca': <Mechnaism(kca)>,
#  'kad': <Mechnaism(kad)>,
#  'mykca': <Mechnaism(mykca)>,
#  'Kdr_soma': <Mechnaism(Kdr_soma)>,
#  'kap': <Mechnaism(kap)>,
#  'cal': <Mechnaism(cal)>,
#  'km': <Mechnaism(km)>}

# %%
def insert_mechanism(mechanism, domains):
    for domain in domains:
        model.insert_mechanism(mechanism, domain, distribute=False)

# %%
apical = ['tuft', 'oblique', 'trunk']
insert_mechanism('Leak', model.domains)
# sodium
insert_mechanism('Na_soma', ['soma', 'axon'])
insert_mechanism('nap', ['tuft', 'oblique'])
insert_mechanism('Na_dend', ['basal', *apical])
# potassium
insert_mechanism('Kdr_soma', ['soma', 'axon'])
insert_mechanism('Kdr_dend', ['basal', *apical])
insert_mechanism('km', ['soma', 'axon', *apical])
insert_mechanism('kad', [*apical])
insert_mechanism('kap', ['trunk', 'oblique', 'basal'])
# misc
insert_mechanism('h', ['soma', 'basal', *apical])

# %%
# calcium
insert_mechanism('cat', ['soma', *apical])
insert_mechanism('car', [*apical])
insert_mechanism('somacar', ['soma'])
insert_mechanism('cal', ['soma'])
insert_mechanism('calH', [*apical])
# calcium-dependent potassium
insert_mechanism('kca', ['soma', *apical])
insert_mechanism('mykca', ['soma', *apical])

# %%
model.distribute_all()

# %%
model.domains_to_mechs
# Out:
# {'oblique': {'Kdr_dend',
#   'Leak',
#   'Na_dend',
#   'calH',
#   'car',
#   'cat',
#   'h',
#   'kad',
#   'kap',
#   'kca',
#   'km',
#   'mykca',
#   'nap'},
#  'basal': {'Kdr_dend', 'Leak', 'Na_dend', 'h', 'kap'},
#  'tuft': {'Kdr_dend',
#   'Leak',
#   'Na_dend',
#   'calH',
#   'car',
#   'cat',
#   'h',
#   'kad',
#   'kca',
#   'km',
#   'mykca',
#   'nap'},
#  'trunk': {'Kdr_dend',
#   'Leak',
#   'Na_dend',
#   'calH',
#   'car',
#   'cat',
#   'h',
#   'kad',
#   'kap',
#   'kca',
#   'km',
#   'mykca'},
#  'axon': {'Kdr_soma', 'Leak', 'Na_soma', 'km'},
#  'soma': {'Kdr_soma',
#   'Leak',
#   'Na_soma',
#   'cal',
#   'cat',
#   'h',
#   'kca',
#   'km',
#   'mykca',
#   'somacar'}}

# %% [markdown]
# # Parameters

# %%
# 0 - 50 - 300 - 350 - ...
model.add_group('proximal_apical', domains=['oblique', 'tuft'], 
    select_by='domain_distance', max_value=50)
model.add_group('medial_apical', domains=['oblique', 'tuft'], 
    select_by='domain_distance', min_value=50, max_value=300)
model.add_group('distal_apical', domains=['oblique', 'tuft'], 
    select_by='domain_distance', min_value=300, max_value=350)
model.add_group('tips_apical', domains=['oblique', 'tuft'], 
    select_by='domain_distance', min_value=350)
model.add_group('non_trunk', domains=['oblique', 'tuft'])
# Out:
# Adding group proximal_apical...
# Adding group medial_apical...
# Adding group distal_apical...
# Adding group tips_apical...
# Adding group non_trunk...

# %%
model.add_group('trunk_less_50', domains=['trunk'], 
    select_by='domain_distance', max_value=50)
model.add_group('trunk_more_50', domains=['trunk'], 
    select_by='domain_distance', min_value=50)
model.add_group('trunk_less_100', domains=['trunk'], 
    select_by='domain_distance', max_value=100)
model.add_group('trunk_more_100', domains=['trunk'], 
    select_by='domain_distance', min_value=100)
model.add_group('trunk_50_200', domains=['trunk'], 
    select_by='domain_distance', min_value=50, max_value=200)
model.add_group('trunk_more_200', domains=['trunk'], 
    select_by='domain_distance', min_value=200)
model.add_group('trunk_more_350', domains=['trunk'], 
    select_by='domain_distance', min_value=350)
model.add_group('trunk_100_350', domains=['trunk'], 
    select_by='domain_distance', min_value=100, max_value=350)
# Out:
# Adding group trunk_less_50...
# Adding group trunk_more_50...
# Adding group trunk_less_100...
# Adding group trunk_more_100...
# Adding group trunk_50_200...
# Adding group trunk_more_200...
# Adding group trunk_more_350...
# Adding group trunk_100_350...

# %%
model.groups
# Out:
# {'all': SegmentGroup("all", domains=['oblique', 'basal', 'tuft', 'trunk', 'axon', 'soma']),
#  'oblique': SegmentGroup("oblique", domains=['oblique']),
#  'basal': SegmentGroup("basal", domains=['basal']),
#  'tuft': SegmentGroup("tuft", domains=['tuft']),
#  'trunk': SegmentGroup("trunk", domains=['trunk']),
#  'axonal': SegmentGroup("axonal", domains=['axon']),
#  'somatic': SegmentGroup("somatic", domains=['soma']),
#  'proximal_apical': SegmentGroup("proximal_apical", domains=['oblique', 'tuft'], domain_distance(None, 50)),
#  'medial_apical': SegmentGroup("medial_apical", domains=['oblique', 'tuft'], domain_distance(50, 300)),
#  'distal_apical': SegmentGroup("distal_apical", domains=['oblique', 'tuft'], domain_distance(300, 350)),
#  'tips_apical': SegmentGroup("tips_apical", domains=['oblique', 'tuft'], domain_distance(350, None)),
#  'non_trunk': SegmentGroup("non_trunk", domains=['oblique', 'tuft']),
#  'trunk_less_50': SegmentGroup("trunk_less_50", domains=['trunk'], domain_distance(None, 50)),
#  'trunk_more_50': SegmentGroup("trunk_more_50", domains=['trunk'], domain_distance(50, None)),
#  'trunk_less_100': SegmentGroup("trunk_less_100", domains=['trunk'], domain_distance(None, 100)),
#  'trunk_more_100': SegmentGroup("trunk_more_100", domains=['trunk'], domain_distance(100, None)),
#  'trunk_50_200': SegmentGroup("trunk_50_200", domains=['trunk'], domain_distance(50, 200)),
#  'trunk_more_200': SegmentGroup("trunk_more_200", domains=['trunk'], domain_distance(200, None)),
#  'trunk_more_350': SegmentGroup("trunk_more_350", domains=['trunk'], domain_distance(350, None)),
#  'trunk_100_350': SegmentGroup("trunk_100_350", domains=['trunk'], domain_distance(100, 350))}

# %%
[k for k in model.params.keys() if k.startswith('g')]
# Out:
# ['gbar_Leak',
#  'gbar_Na_soma',
#  'gbar_nap',
#  'gbar_Na_dend',
#  'gbar_Kdr_soma',
#  'gbar_Kdr_dend',
#  'gbar_km',
#  'gbar_kad',
#  'gbar_kap',
#  'gbar_h',
#  'gbar_cat',
#  'gbar_car',
#  'gbar_somacar',
#  'gbar_cal',
#  'gbar_calH',
#  'gbar_kca',
#  'gbar_mykca']

# %%
model.set_param('Ra', value=50)
model.set_param('Ra', group_name='trunk',
                distr_type='sigmoid',
                vertical_shift = 34.7387906793,
                scale_factor = 14.6740500337,
                growth_rate = -0.0117912091,
                horizontal_shift = 533.9617117381)

# %%
# SOMA
model.set_param('gbar_Leak', group_name='somatic', value=0.000005)
model.set_param('gbar_Na_soma', group_name='somatic', value=0.007)
model.set_param('gbar_Kdr_soma', group_name='somatic', value=0.007 / 5)
model.set_param('gbar_km', group_name='somatic', value=0.06*1e-4)
model.set_param('gbar_h', group_name='somatic', value=1.872e-5)
model.set_param('gbar_kap', group_name='somatic', value=0.0075)
model.set_param('gbar_cal', group_name='somatic', value=0.014/2)
model.set_param('gbar_cat', group_name='somatic', value=0.0001/2)
model.set_param('gbar_somacar', group_name='somatic', value=0.003)
model.set_param('gbar_kca', group_name='somatic', value=5*0.0001)
model.set_param('gbar_mykca', group_name='somatic', value=5.5*1.1*0.015)

# %%
# AXON
model.set_param('gbar_Leak', group_name='axonal', value=0.000005)
model.set_param('gbar_Na_soma', group_name='axonal', value=0.1)
model.set_param('gbar_Kdr_soma', group_name='axonal', value=0.1/5)
model.set_param('gbar_km', group_name='axonal', value=0.5*0.06*1e-4)

# %%
# TRUNK
model.set_param('gbar_Leak', group_name='trunk', distr_type='sigmoid',
                vertical_shift=0.0000061767, #5e-6
                scale_factor=0.0000678359,#7.83e-5,
                growth_rate=0.0165226338,#0.02,
                horizontal_shift=698.1859945614) #340.7
model.set_param('gbar_Na_dend', group_name='trunk', value=0.007)
model.set_param('gbar_Kdr_dend', group_name='trunk', value=0.007 / (10.0 / 1.24))
model.set_param('gbar_km', group_name='trunk', value=0.06*1e-4)

# h
model.set_param('gbar_h', group_name='trunk', distr_type='sigmoid',
                vertical_shift=0.0000213668, #soma_hbar
                scale_factor=0.0001438707, #soma_hbar*9 - soma_hbar
                growth_rate= 0.0145830395, #1/50,
                horizontal_shift=629.7203582338) #280)

# kap
model.set_param('gbar_kap', group_name='trunk_less_50', value=0.0075)

# kad
model.set_param('gbar_kad', group_name='trunk_100_350', distr_type='linear',
                slope=0.0000794365, intercept=-0.0114795265)
model.set_param('gbar_kad', group_name='trunk_more_350', value=6.5*1.04*0.0072)

# kca
model.set_param('gbar_kca', group_name='trunk_less_50', value=0.5*0.0001)
model.set_param('gbar_kca', group_name='trunk_50_200', value=5*0.0001)
model.set_param('gbar_kca', group_name='trunk_more_200', value=0.5*0.0001)
model.set_param('gbar_kca', group_name='trunk_less_50', value=0.25*1.1*0.015)
model.set_param('gbar_kca', group_name='trunk_50_200', value=2*1.1*0.015)
model.set_param('gbar_kca', group_name='trunk_more_200', value=0.25*1.1*0.015)

# cat
# model.set_param('gbar_cat', group_name='trunk_less_100', value=???)
model.set_param('gbar_cat', group_name='trunk_more_100', distr_type='linear',
intercept=-0.0001041345, slope=0.0000006745)

# car
model.set_param('gbar_car', group_name='trunk_less_100', value=0.1*0.0003)

# calH
model.set_param('gbar_calH', group_name='trunk_less_50', value=0.1*0.95*0.000333)
model.set_param('gbar_calH', group_name='trunk_more_50', value=4.6*0.95*0.000333)

# %%
nexus = model.sec_tree[86]

hold_leak = nexus(0.5).get_param_value('gbar_Leak')
hold_cat = nexus(0.5).get_param_value('gbar_cat')
hold_h = nexus(0.5).get_param_value('gbar_h')
hold_kdr = nexus(0.5).get_param_value('gbar_Kdr_dend')
hold_kap = nexus(0.5).get_param_value('gbar_kap')
hold_kad = nexus(0.5).get_param_value('gbar_kad')
hold_mykca = nexus(0.5).get_param_value('gbar_mykca')
hold_kca = nexus(0.5).get_param_value('gbar_kca')
hold_km = nexus(0.5).get_param_value('gbar_km')

# %%
# NON-TRUNK

model.set_param('gbar_Na_dend', group_name='non_trunk', value=0.007)

model.set_param('gbar_Leak', group_name='medial_apical', value=hold_leak)
model.set_param('gbar_nap', group_name='medial_apical', value=0.0004*0.007)
model.set_param('gbar_Kdr_dend', group_name='medial_apical', value=0.007/ (10.0 / 1.24))
model.set_param('gbar_kap', group_name='medial_apical', value=hold_kap)
model.set_param('gbar_kad', group_name='medial_apical', value=1.25*hold_kad)
model.set_param('gbar_h', group_name='medial_apical', value=hold_h)
model.set_param('gbar_km', group_name='medial_apical', value=2*hold_km)
model.set_param('gbar_kca', group_name='medial_apical', value=hold_kca)
model.set_param('gbar_mykca', group_name='medial_apical', value=1.1*0.015)
model.set_param('gbar_cat', group_name='medial_apical', value=hold_cat)
model.set_param('gbar_car', group_name='medial_apical', value=0.0003)
model.set_param('gbar_calH', group_name='medial_apical', value=0.95*0.000333)

# DISTAL_APICAL
model.set_param('gbar_Leak', group_name='distal_apical', value=hold_leak)
model.set_param('gbar_nap', group_name='distal_apical', value=0.0004*0.007)
model.set_param('gbar_Kdr_dend', group_name='distal_apical', value=1.07*hold_kdr)
model.set_param('gbar_kap', group_name='distal_apical', value=hold_kap)
model.set_param('gbar_kad', group_name='distal_apical', value=1.3*1.9*hold_kad)
model.set_param('gbar_h', group_name='distal_apical', value=hold_h)
model.set_param('gbar_km', group_name='distal_apical', value=2*hold_km)
model.set_param('gbar_kca', group_name='distal_apical', value=5*0.0001)
model.set_param('gbar_mykca', group_name='distal_apical', value=1.1*0.015)
model.set_param('gbar_cat', group_name='distal_apical', value=hold_cat)
model.set_param('gbar_car', group_name='distal_apical', value=13*0.0003)
model.set_param('gbar_calH', group_name='distal_apical', value=14*0.95*0.000333)

# TIPS
# model.set_param('gbar_Leak', group_name='tips', value=hold_leak)
# model.set_param('gbar_nap', group_name='tips', value=0.0004*0.007)
# model.set_param('gbar_Kdr_dend', group_name='tips', value=0.007 / (10.0 / 1.24))
# model.set_param('gbar_kap', group_name='tips', value=hold_kap)
# model.set_param('gbar_kad', group_name='tips', value=1.25*hold_kad)
# model.set_param('gbar_h', group_name='tips', value=hold_h)
# model.set_param('gbar_km', group_name='tips', value=2*hold_km)
# model.set_param('gbar_kca', group_name='tips', value=hold_kca)
# model.set_param('gbar_mykca', group_name='tips', value=1.1*0.015)
# model.set_param('gbar_cat', group_name='tips', value=hold_cat)
# model.set_param('gbar_car', group_name='tips', value=0.0003)
# model.set_param('gbar_calH', group_name='tips', value=0.95*0.000333)

# %%
# BASAL
sec = model.sec_tree[65]
hold_kap = sec(0.5).get_param_value('gbar_kap')
hold_kad = sec(0.5).get_param_value('gbar_kad')
hold_leak = sec(0.5).get_param_value('gbar_Leak')

model.set_param('gbar_Leak', group_name='basal', value=hold_leak)
model.set_param('gbar_Na_dend', group_name='basal', value=0.007)
model.set_param('gbar_Kdr_dend', group_name='basal', value=0.007 / (10.0 / 1.24))
model.set_param('gbar_kap', group_name='basal', value=1.6*hold_kap)
# model.set_param('gbar_kad', group_name='basal', value=1.6*hold_kad)
model.set_param('gbar_h', group_name='basal', value=1.872e-5)

# %%
model.set_param('K_h', group_name='somatic', value=8.8)
model.set_param('vhalf_h', group_name='somatic', value=-82)

# %%
model.df_params['Distribution params']
# Out:
# 0                                          {'value': 1}
# 1                                         {'value': 50}
# 2     {'vertical_shift': 34.7387906793, 'scale_facto...
# 3                                         {'value': 50}
# 4                                        {'value': -77}
#                             ...
# 88                                    {'value': 0.0005}
# 89                                       {'value': 0.0}
# 90                       {'value': 0.09075000000000001}
# 91                                    {'value': 0.0165}
# 92                                    {'value': 0.0165}
# Name: Distribution params, Length: 93, dtype: object

# %%
for param_name in model.conductances:
    fig, ax = plt.subplots(figsize=(10, 2))
    model.plot_param(param_name, ax=ax)

# %%
model.set_param('e_Leak', value=-70)
model.set_param('ena', value=50)
model.set_param('ek', value=-80)
model.set_param('eca', value=120)
model.set_param('temperature', value=34)
model.set_param('v_init', value=-70)

# %%
model.export_membrane(version='test2')

# %%
soma = model.sec_tree.soma
soma
# Out:
# ••0

# %%
model.add_recording(soma, loc=0.5)

# %%
model.remove_all_iclamps()
model.add_iclamp(soma, loc=0.5, amp=0.22, delay=100, dur=100)
# Out:
# IClamp added to sec ••0 at loc 0.5.

# %%
t, vs, _ = model.simulator.run(300);

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
model.simulator.plot_voltage(ax=ax)

# %%
model.export_stimuli(version='test');
# Out:
# {'type': ['recording'], 'idx': [0], 'sec_idx': [0], 'loc': [0.5], 'n_per_seg': [1]}
